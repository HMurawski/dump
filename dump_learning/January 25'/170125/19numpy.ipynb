# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Operacje logiczne
arr = np.array([3,8,1,10,5,7])

mask = np.logical_and(arr > 5, arr <10)
mask_or= np.logical_or(arr > 5, arr <10)

print(arr[mask])
print(arr[mask_or])

mask_not = np.logical_not(arr > 5)
print(arr[mask_not])
# Out:
# [8 7]
# [ 3  8  1 10  5  7]
# [3 1 5]

# %%
#Sortowanie
arr = np.array([12,3,7,5,8,2,9])
sorted_arr = np.sort(arr)
print(sorted_arr)
args = np.argsort(arr)
print(args)
# Out:
# [ 2  3  5  7  8  9 12]
# [5 1 3 2 4 6 0]

# %%
#unikalne wartości
t = np.array([4,7,2,4,7,1,1,7])
u_values = np.unique(t)
print(u_values)

wystapienia = np.bincount(t)
for i, z in enumerate(wystapienia):
    print(f"Wartość: {i}:{z}razy")
# Out:
# [1 2 4 7]
# Wartość: 0:0razy
# Wartość: 1:2razy
# Wartość: 2:1razy
# Wartość: 3:0razy
# Wartość: 4:2razy
# Wartość: 5:0razy
# Wartość: 6:0razy
# Wartość: 7:3razy

# %%
#Zadanie łączące
tab = np.random.randint(low=1, high=21, size=(4,5))
mask = np.logical_and(tab > 10, tab%2==0)
checked = tab[mask]
print(checked)

col_sorted = np.sort(tab, axis=0)
print(col_sorted)

uniques = np.unique(tab, axis=0)
print(uniques)
# Out:
# [14 14 18]
# [[ 7  4  4  5  2]
#  [ 9  5 11  5 13]
#  [10 11 14  6 13]
#  [17 13 18 19 14]]
# [[ 7 11 18 19 13]
#  [ 9 13 11  5 13]
#  [10  5  4  6  2]
#  [17  4 14  5 14]]

# %%
np.random.seed(42)
regions = ['North', 'South', 'East', 'West']
stores = ['Store_A', 'Store_B', 'Store_C', 'Store_D', 'Store_E']

data = pd.DataFrame({
    'Store': np.random.choice(stores, size=20),
    'Region': np.random.choice(regions, size=20),
    'Sales': np.random.randint(2000, 5000, size=20)
})
print(data.head(2))
# Out:
#      Store Region  Sales
# 0  Store_D  South   3899
# 1  Store_E  South   3267

# %%
total_sales = data.groupby("Region")["Sales"].sum()

total_sales.plot(kind='bar', figsize=(6,4), title="Sales by Region", colormap='viridis', grid=True, alpha=0.7, legend=True)
plt.xlabel("Region")
plt.ylabel("Sales")
plt.grid(axis='y', linestyle="--", alpha=0.6)
for i, value in enumerate(total_sales):
    plt.text(i, value + 100, f"{value}", ha='center', va='bottom', fontsize=10)

# %%
#Store Region  Sales
pivot = data.pivot_table(values="Sales", columns="Region", index="Store", aggfunc="sum", fill_value=0)
print(pivot)
# Out:
# Region    East  North  South  West
# Store
# Store_A      0      0   3363     0
# Store_B      0   4068   4824  2241
# Store_C  12399   4879      0  4363
# Store_D   8180      0   8511  2600
# Store_E   4945   2646   7702  7589

# %%
pivot.style.background_gradient(cmap="viridis").set_properties(**{'font-size': '14px'})
# Out:
# <style type="text/css">
# #T_7ae79_row0_col0, #T_7ae79_row0_col1, #T_7ae79_row0_col3, #T_7ae79_row1_col0, #T_7ae79_row2_col2, #T_7ae79_row3_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row0_col2 {
#   background-color: #2a778e;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row1_col1 {
#   background-color: #90d743;
#   color: #000000;
#   font-size: 14px;
# }
# #T_7ae79_row1_col2 {
#   background-color: #1fa188;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row1_col3 {
#   background-color: #355e8d;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row2_col0, #T_7ae79_row2_col1, #T_7ae79_row3_col2, #T_7ae79_row4_col3 {
#   background-color: #fde725;
#   color: #000000;
#   font-size: 14px;
# }
# #T_7ae79_row2_col3 {
#   background-color: #1fa287;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row3_col0 {
#   background-color: #32b67a;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row3_col3 {
#   background-color: #306a8e;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row4_col0 {
#   background-color: #2a788e;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row4_col1 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
#   font-size: 14px;
# }
# #T_7ae79_row4_col2 {
#   background-color: #c0df25;
#   color: #000000;
#   font-size: 14px;
# }
# </style>
# <table id="T_7ae79">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th id="T_7ae79_level0_col0" class="col_heading level0 col0" >East</th>
#       <th id="T_7ae79_level0_col1" class="col_heading level0 col1" >North</th>
#       <th id="T_7ae79_level0_col2" class="col_heading level0 col2" >South</th>
#       <th id="T_7ae79_level0_col3" class="col_heading level0 col3" >West</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ae79_level0_row0" class="row_heading level0 row0" >Store_A</th>
#       <td id="T_7ae79_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_7ae79_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_7ae79_row0_col2" class="data row0 col2" >3363</td>
#       <td id="T_7ae79_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7ae79_level0_row1" class="row_heading level0 row1" >Store_B</th>
#       <td id="T_7ae79_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_7ae79_row1_col1" class="data row1 col1" >4068</td>
#       <td id="T_7ae79_row1_col2" class="data row1 col2" >4824</td>
#       <td id="T_7ae79_row1_col3" class="data row1 col3" >2241</td>
#     </tr>
#     <tr>
#       <th id="T_7ae79_level0_row2" class="row_heading level0 row2" >Store_C</th>
#       <td id="T_7ae79_row2_col0" class="data row2 col0" >12399</td>
#       <td id="T_7ae79_row2_col1" class="data row2 col1" >4879</td>
#       <td id="T_7ae79_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_7ae79_row2_col3" class="data row2 col3" >4363</td>
#     </tr>
#     <tr>
#       <th id="T_7ae79_level0_row3" class="row_heading level0 row3" >Store_D</th>
#       <td id="T_7ae79_row3_col0" class="data row3 col0" >8180</td>
#       <td id="T_7ae79_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_7ae79_row3_col2" class="data row3 col2" >8511</td>
#       <td id="T_7ae79_row3_col3" class="data row3 col3" >2600</td>
#     </tr>
#     <tr>
#       <th id="T_7ae79_level0_row4" class="row_heading level0 row4" >Store_E</th>
#       <td id="T_7ae79_row4_col0" class="data row4 col0" >4945</td>
#       <td id="T_7ae79_row4_col1" class="data row4 col1" >2646</td>
#       <td id="T_7ae79_row4_col2" class="data row4 col2" >7702</td>
#       <td id="T_7ae79_row4_col3" class="data row4 col3" >7589</td>
#     </tr>
#   </tbody>
# </table>

# %%
store_a = data[data["Store"] == "Store_A"]
store_b = data[data["Store"] == "Store_B"]
# Out:
#       Store Region  Sales
# 5   Store_B  North   4068
# 13  Store_B   West   2241
# 15  Store_B  South   4824

# %%
np.random.seed(42)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
stores = ['Store_A', 'Store_B', 'Store_C', 'Store_D', 'Store_E']


data = pd.DataFrame(
    np.random.randint(2000, 5000, size=(6, 5)),  # Losowe dane sprzedaży
    index=months,  # Miesiące jako indeks
    columns=stores  # Nazwy sklepów jako kolumny
)

print(data)  # Sprawdzenie, czy kolumny istnieją

# Wybór danych dla Store_A i Store_B
if "Store_A" in data.columns and "Store_B" in data.columns:
    store_a = data["Store_A"]
    store_b = data["Store_B"]
else:
    print("Kolumny Store_A i Store_B nie istnieją w danych!")

# Tworzenie wykresu
ax = store_a.plot(
    figsize=(10, 6),
    linewidth=2,
    marker='o',
    color='blue',
    label='Store_A Sales',
    title="Comparison of Sales for Store_A and Store_B"
)

# Dodanie Store_B na osobnej osi Y
store_b.plot(
    secondary_y=True,
    linewidth=2,
    marker='o',
    color='orange',
    label='Store_B Sales',
    ax=ax
)

# Dodanie etykiet i legendy
ax.set_xlabel("Month")
ax.set_ylabel("Store_A Sales")
ax.right_ax.set_ylabel("Store_B Sales")
ax.grid(visible=True, linestyle="--", alpha=0.7)
ax.legend(loc="upper left")
ax.right_ax.legend(loc="upper right")

# Wyświetlenie wykresu
plt.tight_layout()
plt.show()
# Out:
#      Store_A  Store_B  Store_C  Store_D  Store_E
# Jan     2860     3294     3130     3095     3638
# Feb     4169     2466     3238     2330     3482
# Mar     4135     4919     2130     3685     2769
# Apr     4391     3515     4853     4433     3215
# May     2955     4324     3184     2459     2021
# Jun     4300     2747     4904     2474     3082
