# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("datasets\\salaries.csv")
df.head()
# Out:
#    Years of Experience  Education Level  Age  Location Factor  Salary
# 0                   29                1   49                7  124204
# 1                   27                3   45                4  125948
# 2                   20                4   41                8  116078
# 3                   14                4   37                5  106486
# 4                   20                3   42                7  113297

# %%
df.shape
# Out:
# (1000, 5)

# %%
X = df.drop("Salary", axis=1)
y = df["Salary"]

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, train_size=0.8)
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test, y_test)
# Out:
# 0.959406861351375

# %%
model.coef_, model.intercept_
# Out:
# (array([2109.51761869, 5060.61877537, -120.2791406 , 1495.70225789]),
#  52519.183036886585)

# %%
cm = df.corr()
sns.heatmap(cm, annot=True, fmt=".2f")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df):
    vif_df = pd.DataFrame()
    vif_df["Variable"] = df.columns
    vif_df["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif_df

# %%
X = df.drop("Salary", axis=1)
calculate_vif(X)
# Out:
#               Variable        VIF
# 0  Years of Experience  22.342087
# 1      Education Level   5.472969
# 2                  Age  42.201149
# 3      Location Factor   4.289467

# %%
calculate_vif(X.drop("Age", axis=1))
# Out:
#               Variable       VIF
# 0  Years of Experience  3.198601
# 1      Education Level  3.509425
# 2      Location Factor  3.231181

# %%
df = df[["Years of Experience", "Education Level", "Location Factor", "Salary"]]
df.head()
# Out:
#    Years of Experience  Education Level  Location Factor  Salary
# 0                   29                1                7  124204
# 1                   27                3                4  125948
# 2                   20                4                8  116078
# 3                   14                4                5  106486
# 4                   20                3                7  113297

# %%
X = df.drop("Salary", axis=1)
y = df["Salary"]

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, train_size=0.8)
model = LinearRegression()
model.fit(X_train,y_train)
model.score(X_test, y_test)
# Out:
# 0.9592314656682582

# %%
model.coef_, model.intercept_
# Out:
# (array([1994.10983096, 5070.62814345, 1500.8453815 ]), 49934.24068274489)
