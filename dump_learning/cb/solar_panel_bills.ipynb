# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("bill_survey.csv")
df.sample(3)
# Out:
#           City   Bill
# 9379      Rewa  13700
# 1077      Agra   5200
# 5661  Bhatpara   2600

# %%
df.shape
# Out:
# (10350, 2)

# %%
df.describe()
# Out:
#               Bill
# count  10350.00000
# mean    5951.52657
# std     4193.19317
# min      100.00000
# 25%     2900.00000
# 50%     5000.00000
# 75%     8000.00000
# max    38900.00000

# %%
df["City"].nunique()
# Out:
# 207

# %%
sns.histplot(df["Bill"], kde=True)

plt.show()

# %%
mumbai_bill = df[df["City"] == "Mumbai"]["Bill"]
mumbai_bill.head()
# Out:
# 0    15400
# 1     6700
# 2    16300
# 3     2100
# 4     4600
# Name: Bill, dtype: int64

# %%
sns.histplot(mumbai_bill, kde=True)

plt.show()

# %%
sample_means = []
for city, subdf in df.groupby("City"):
    sample_means.append(subdf["Bill"].mean())
sample_means[:3]
print(len(sample_means))
# Out:
# 207

# %%
sns.histplot(sample_means, kde=True)
# Out:
# <Axes: ylabel='Count'>
